# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load imports.py
import pandas as pd
import numpy as np
from scipy.misc import imread, imsave, imresize
import matplotlib.pyplot as plt

# %%
# %run traffic_util.py

# %%
X_train, y_train, X_test, y_test = traffic_load("../../../data")

# %%
traffic_hist(y_train)
traffic_hist(y_test)

# %%
X_train, X_test = traffic_resize(X_train, X_test, 2)

print 'Training data new shape: ', X_train.shape
print 'Test data new shape: ', X_test.shape

display_subsample(3, X_train, y_train)
# Out:
# Training data new shape:  (2087L, 120L, 160L, 3L)
# Test data new shape:  (525L, 120L, 160L, 3L)

# %%
X_train, X_test = traffic_2grey(X_train, X_test)

display_subsample(3, X_train, y_train)

# %%
# Not implemented yet
X_train, X_test = traffic_separate_bg(X_train, X_test)

display_subsample(3, X_train, y_train)

# %%
# TODO: feature extraction part here
