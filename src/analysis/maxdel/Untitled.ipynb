# %%
# %matplotlib inline

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import pandas as pd
from scipy.misc import imread, imsave, imresize

# %%
# %run features.py

# %%
# %run traffic_util.py

# %%
X_train, y_train, X_test, y_test = traffic_load("../../../data")

# %%
##X_train, X_test = traffic_resize(X_train, X_test, 2)

# %%
X_train_g = map(lambda x : cv2.cvtColor(x,cv2.COLOR_BGR2GRAY), X_train)

# %%
info_train, info_test = traffic_info_load("../../../data")

# %%
# Lets do everything for train data

# 1) Find corners
def imgs2corners(img_list):
    return map(lambda x : np.int0(cv2.goodFeaturesToTrack(x,100,0.01,10)), img_list)

# %%
corners = imgs2corners(X_train_g)
len(corners[])
# Out:
# 100

# %%
len(corners[10000])
# Out:
# 100

# %%
plt.figure(figsize = (20,20))

for i in corners[0]:
    x,y = i.ravel()
    cv2.circle(X_train[0],(x,y),3, (255,0,0))   
plt.subplot(1, 3, 1)
plt.imshow(X_train[0])

for i in corners[1]:
    x,y = i.ravel()
    cv2.circle(X_train[1],(x,y),3, (255,0,0))
plt.subplot(1, 3, 2)
plt.imshow(X_train[1])

for i in corners[2]:
    x,y = i.ravel()
    cv2.circle(X_train[2],(x,y),3, (255,0,0))
plt.subplot(1, 3, 3)
plt.imshow(X_train[2])

# %%
video_inds = set(info_train)
print len(video_inds)
# Out:
# 203

# %%
corners_all = []
for video_ind in video_inds:
    frames = X_train[info_train == video_ind]
    corners_all = np.append(corners_all, imgs2corners(frames), axis=0)
        
print corners_all.shape
# Out:
# (2087L,)

# %%
corners

# %%
#Draw corners as cirles
corners = corners_all

plt.figure(figsize = (20,20))

for i in corners[0]:
    x,y = i.ravel()
    cv2.circle(img_list[0],(x,y),3, (255,0,0))   
plt.subplot(1, 3, 1)
plt.imshow(img_list[0])

for i in corners[1]:
    x,y = i.ravel()
    cv2.circle(img_list[1],(x,y),3, (255,0,0))
plt.subplot(1, 3, 2)
plt.imshow(img_list[1])

for i in corners[2]:
    x,y = i.ravel()
    cv2.circle(img_list[2],(x,y),3, (255,0,0))
plt.subplot(1, 3, 3)
plt.imshow(img_list[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-a67845380dfa> in <module>()
#       6 for i in corners[0]:
#       7     x,y = i.ravel()
# ----> 8     cv2.circle(img_list[0],(x,y),3, (255,0,0))
#       9 plt.subplot(1, 3, 1)
#      10 plt.imshow(img_list[0])
#
# NameError: name 'img_list' is not defined
